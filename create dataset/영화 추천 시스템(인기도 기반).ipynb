# %% [markdown]
# # 영화 추천 시스템
# ## Demographic Filtering (인구통계학적 필터링)

# %%
import pandas as pd
import numpy as np

df = pd.read_json('all_movies.json')

# %%
df.head()
# Out:
#    adult                     backdrop_path            genre_ids       id  \
# 0  False  /2Nti3gYAX513wvhp8IiLL6ZDyOm.jpg  [10751, 35, 12, 14]   950387
# 1  False  /tyfO9jHgkhypUFizRVYD0bytPjP.jpg          [10751, 14]   447273
# 2  False  /j0NUh5irX7q2jIRtbLo8TZyRn6y.jpg       [27, 9648, 35]   574475
# 3  False  /cJvUJEEQ86LSjl4gFLkYpdCJC96.jpg          [10752, 28]  1241436
# 4  False  /fTrQsdMS2MUw00RnzH0r3JWHhts.jpg         [28, 80, 53]  1197306
#
#   original_language                original_title  \
# 0                en             A Minecraft Movie
# 1                en                    Snow White
# 2                en  Final Destination Bloodlines
# 3                en                       Warfare
# 4                en                 A Working Man
#
#                                             overview  popularity  \
# 0  왕년의 게임 챔피언이었지만 지금은 폐업 직전의 게임샵 주인이 된 '개릿'과 엄마를 ...    868.2685
# 1  눈보라가 몰아치던 겨울 밤 태어난 백설공주. 온정이 넘치던 왕국에서 모두의 사랑을 ...    387.4897
# ...

# %%
df.shape
# Out:
# (9979, 14)

# %%
df.columns
# Out:
# Index(['adult', 'backdrop_path', 'genre_ids', 'id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'release_date', 'title', 'video', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
q_movies = df.copy()

# %%
q_movies['popularity'].sort_values()
# Out:
# 6188      0.5074
# 9451      0.5437
# 9773      0.5667
# 9478      0.6180
# 8975      0.6515
#           ...
# 4       357.3065
# 3       379.8887
# 2       386.4101
# 1       387.4897
# 0       868.2685
# Name: popularity, Length: 9979, dtype: float64

# %%
q_movies.head()
# Out:
#    adult                     backdrop_path            genre_ids       id  \
# 0  False  /2Nti3gYAX513wvhp8IiLL6ZDyOm.jpg  [10751, 35, 12, 14]   950387
# 1  False  /tyfO9jHgkhypUFizRVYD0bytPjP.jpg          [10751, 14]   447273
# 2  False  /j0NUh5irX7q2jIRtbLo8TZyRn6y.jpg       [27, 9648, 35]   574475
# 3  False  /cJvUJEEQ86LSjl4gFLkYpdCJC96.jpg          [10752, 28]  1241436
# 4  False  /fTrQsdMS2MUw00RnzH0r3JWHhts.jpg         [28, 80, 53]  1197306
#
#   original_language                original_title  \
# 0                en             A Minecraft Movie
# 1                en                    Snow White
# 2                en  Final Destination Bloodlines
# 3                en                       Warfare
# 4                en                 A Working Man
#
#                                             overview  popularity  \
# 0  왕년의 게임 챔피언이었지만 지금은 폐업 직전의 게임샵 주인이 된 '개릿'과 엄마를 ...    868.2685
# 1  눈보라가 몰아치던 겨울 밤 태어난 백설공주. 온정이 넘치던 왕국에서 모두의 사랑을 ...    387.4897
# ...

# %%
q_movies[['title', 'genre_ids', 'id', 'popularity']].head(10)
# Out:
#                          title            genre_ids       id  popularity
# 0  A MINECRAFT MOVIE 마인크래프트 무비  [10751, 35, 12, 14]   950387    868.2685
# 1                         백설공주          [10751, 14]   447273    387.4897
# 2            파이널 데스티네이션: 블러드라인       [27, 9648, 35]   574475    386.4101
# 3                          워페어          [10752, 28]  1241436    379.8887
# 4                          워킹맨         [28, 80, 53]  1197306    357.3065
# 5                         더 솔져             [28, 53]   977294    315.1708
# 6                     사라진 탄환 3     [28, 80, 53, 18]  1144430    217.7879
# 7                        썬더볼츠*        [28, 878, 12]   986056    228.4211
# 8                       용감한 시민         [28, 18, 35]   897160    198.1060
# 9           Conjuring the Cult             [27, 18]  1359977    199.8900

# %%
q_movies[['title', 'genre_ids', 'id', 'poster_path', 'popularity']].to_json("movies_popularity.json", orient='records', force_ascii=False, indent=2)
